# %%
import pandas as pd
df2 = pd.read_csv('nfl_elo_latest.csv')
df2.head()
# Out:
#          date  season  neutral playoff team1 team2     elo1_pre     elo2_pre  \
# 0  2019-09-05    2019        0     NaN   CHI    GB  1588.897931  1455.131370
# 1  2019-09-08    2019        0     NaN   CAR   LAR  1519.378772  1598.015666
# 2  2019-09-08    2019        0     NaN   NYJ   BUF  1384.966442  1448.423682
# 3  2019-09-08    2019        0     NaN   PHI   WSH  1581.513559  1441.021792
# 4  2019-09-08    2019        0     NaN   JAX    KC  1455.249073  1602.077427
#
#    elo_prob1  elo_prob2  ...  qbelo_prob1  qbelo_prob2  qb1_game_value  \
# 0   0.758449   0.241551  ...     0.640182     0.359818      -36.627083
# 1   0.480385   0.519615  ...     0.475030     0.524970       49.375757
# 2   0.502220   0.497780  ...     0.546114     0.453886      112.062742
# 3   0.765470   0.234530  ...     0.774390     0.225610      355.544272
# 4   0.384370   0.615630  ...     0.415645     0.584355       88.354740
#
# ...

# %%
df2.shape
# Out:
# (267, 30)
